# %%
from nyc_data_pipeline.source_extract_async import *

# %%
import asyncio
from bs4 import BeautifulSoup
import logging
import subprocess
import aiohttp
import os
import random
# [Include the class definitions of NYCPublicDataFetcher, NYCEndpointFetcher, and NYCUrlFetcher here]

# Initialize logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
async def fetch_311_data(start_url):
    logging.info("Starting the 311 data fetching process")
    
    public_data_fetcher = NYCPublicDataFetcher(start_url)
    endpoint_fetcher = NYCEndpointFetcher()
    url_fetcher = NYCUrlFetcher()

    logging.info("Fetching initial data")
    initial_data = await url_fetcher.run(start_url)
    if not initial_data:
        logging.error("Failed to fetch initial data")
        return

    logging.info("Fetching main content data")
    main_content_data = await public_data_fetcher.run()
    if not main_content_data:
        logging.error("Failed to fetch main content data")
        return

    logging.info("Fetching detailed endpoint data")
    detailed_data = await endpoint_fetcher.run(main_content_data)
    if not detailed_data:
        logging.error("Failed to fetch detailed endpoint data")
        return

    logging.info("Data fetching process completed")
    return detailed_data

# %%
# Define the starting URL for the 311 data
start_url = 'https://data.cityofnewyork.us/browse?category=311'

# Asynchronous function to run the fetchers
data = await fetch_311_data(start_url)
# Out:
# 2024-01-20 12:33:06,160 - INFO - Starting the 311 data fetching process
# 2024-01-20 12:33:06,164 - INFO - Fetching initial data
# 2024-01-20 12:33:09,346 - ERROR - Failed to fetch initial data

# %%
class NYCPipeline:
    
    def __init__(self, urls, bucket_name):
        self.urls = urls
        self.bucket_name = bucket_name
        self.endpoints = {}
        # self.manager = OortLandingZoneManager(bucket_name=self.bucket_name)
        # self.pipeline_manager = UnifiedPipelineManager()

    async def fetch_endpoints_from_url(self, url):
        data_fetcher = NYCPublicDataFetcher(url)
        data_dict = await data_fetcher.run()
        data_dict = {url.split('/')[-2]: url.lower() for _, url in data_dict.items()}
        endpoint_fetcher = NYCEndpointFetcher()
        endpoints = await endpoint_fetcher.run(data_dict)
        return endpoints

    async def fetch_all_endpoints(self):
        tasks = [self.fetch_endpoints_from_url(url) for url in self.urls]
        results = await asyncio.gather(*tasks)
        for endpoints in results:
            self.endpoints.update(endpoints)
        
    async def save_data_to_file(self, data, filename):
        with open(filename, 'w') as file:
            file.write(data)
    
    async def run(self):
        logging.info("Starting the NYCPipeline process")
        
        # Fetch all endpoints from the provided URLs
        logging.info("Fetching all endpoints from URLs")
        await self.fetch_all_endpoints()

        # Dictionary to store data
        data_dict = {}

        # Save the fetched data in the dictionary
        for key, endpoint in self.endpoints.items():
            identifier = f"{key}"  # or any other naming scheme you prefer
            logging.info(f"Saving data for {key}")
            data_dict[identifier] = endpoint

        logging.info("NYCPipeline process completed")

        # Return the dictionary with data
        return data_dict

# %%
# Initialize the pipeline
pipeline = NYCPipeline(urls=["https://data.cityofnewyork.us/browse?q=311"], bucket_name="your_bucket_name")

# Run the pipeline and get the data dictionary
data_dict = await pipeline.run()

# Now, data_dict contains your data
# You can process it as you need
# Out:
# 2024-01-20 13:11:35,122 - INFO - Starting the NYCPipeline process
# 2024-01-20 13:11:35,129 - INFO - Fetching all endpoints from URLs
# 2024-01-20 13:11:42,201 - WARNING - Couldn't find endpoint for s
# 2024-01-20 13:11:50,992 - WARNING - Couldn't find endpoint for DOT-Street-Lights-and-Traffic-Signals-311-Service-
# 2024-01-20 13:11:56,005 - WARNING - Couldn't find endpoint for Parking-Meters-Locations-and-Status-Map-
# 2024-01-20 13:11:58,564 - WARNING - Couldn't find endpoint for Hurricane-Evacuation-Centers-Map-
# 2024-01-20 13:12:01,075 - WARNING - Couldn't find endpoint for Overhead-Electronic-Signs-Map-
# 2024-01-20 13:12:01,083 - INFO - Saving data for 311-Service-Requests-from-2010-to-Present
# 2024-01-20 13:12:01,083 - INFO - Saving data for 311-Service-Requests-for-2009
# 2024-01-20 13:12:01,084 - INFO - Saving data for 311-Call-Center-Inquiry
# 2024-01-20 13:12:01,084 - INFO - Saving data for 311-Service-Requests-for-2004
# 2024-01-20 13:12:01,084 - INFO - Saving data for 311-Service-Requests-for-2007
# 2024-01-20 13:12:01,084 - INFO - Saving data for 311-Service-Level-Agreements
# 2024-01-20 13:12:01,084 - INFO - Saving data for 311-Web-Content-Services
# 2024-01-20 13:12:01,085 - INFO - Saving data for 311-Service-Requests-for-2008
# 2024-01-20 13:12:01,085 - INFO - Saving data for 311-Service-Requests-for-2006
# 2024-01-20 13:12:01,085 - INFO - Saving data for 311-Service-Requests-for-2005
# 2024-01-20 13:12:01,085 - INFO - Saving data for 311-Interpreter-Wait-Time
# 2024-01-20 13:12:01,085 - INFO - Saving data for DOHMH-Call-Center-Summary
# 2024-01-20 13:12:01,085 - INFO - Saving data for SCOUT-Street-Condition-Observation-Unit-
# 2024-01-20 13:12:01,085 - INFO - Saving data for Commissioner-s-Correspondence
# 2024-01-20 13:12:01,086 - INFO - Saving data for Local-Law-8-of-2020-Report-Monthly-Complaints-of-I
# 2024-01-20 13:12:01,086 - INFO - Saving data for DOHMH-Indoor-Environmental-Complaints
# 2024-01-20 13:12:01,086 - INFO - Saving data for Local-Law-8-of-2020-Complaints-of-Illegal-Parking-
# 2024-01-20 13:12:01,086 - INFO - Saving data for Forestry-Service-Requests
# 2024-01-20 13:12:01,086 - INFO - Saving data for Inspections-of-Municipal-Solid-Waste-Disposal-Loca
# 2024-01-20 13:12:01,086 - INFO - Saving data for Curb-Metal-Data
# 2024-01-20 13:12:01,087 - INFO - NYCPipeline process completed

# %%
print(data_dict)
# Out:
# {'311-Service-Requests-from-2010-to-Present': 'https://data.cityofnewyork.us/resource/erm2-nwe9.json', '311-Service-Requests-for-2009': 'https://data.cityofnewyork.us/resource/3rfa-3xsf.json', '311-Call-Center-Inquiry': 'https://data.cityofnewyork.us/resource/wewp-mm3p.json', '311-Service-Requests-for-2004': 'https://data.cityofnewyork.us/resource/sqcr-6mww.json', '311-Service-Requests-for-2007': 'https://data.cityofnewyork.us/resource/aiww-p3af.json', '311-Service-Level-Agreements': 'https://data.cityofnewyork.us/resource/cs9t-e3x8.json', '311-Web-Content-Services': 'https://data.cityofnewyork.us/resource/vwpc-kje2.json', '311-Service-Requests-for-2008': 'https://data.cityofnewyork.us/resource/uzcy-9puk.json', '311-Service-Requests-for-2006': 'https://data.cityofnewyork.us/resource/hy4q-igkk.json', '311-Service-Requests-for-2005': 'https://data.cityofnewyork.us/resource/sxmw-f24h.json', '311-Interpreter-Wait-Time': 'https://data.cityofnewyork.us/resource/dzvt-6g3v.json', 'DOHMH-Call-Center-Summary': 'https://data.cityofnewyork.us/resource/wymh-dvmd.json', 'SCOUT-Street-Condition-Observation-Unit-': 'https://data.cityofnewyork.us/resource/kjxa-7ccf.json', 'Commissioner-s-Correspondence': 'https://data.cityofnewyork.us/resource/b4mf-rg6h.json', 'Local-Law-8-of-2020-Report-Monthly-Complaints-of-I': 'https://data.cityofnewyork.us/resource/9y7k-h295.json', 'DOHMH-Indoor-Environmental-Complaints': 'https://data.cityofnewyork.us/resource/9jgj-bmct.json', 'Local-Law-8-of-2020-Complaints-of-Illegal-Parking-': 'https://data.cityofnewyork.us/resource/cwy2-px8b.json', 'Forestry-Service-Requests': 'https://data.cityofnewyork.us/resource/mu46-p9is.json', 'Inspections-of-Municipal-Solid-Waste-Disposal-Loca': 'https://data.cityofnewyork.us/resource/rn6p-xvjd.json', 'Curb-Metal-Data': 'https://data.cityofnewyork.us/resource/i2y3-sx2e.json'}

# %%
import os
import logging
import asyncio
import aiohttp

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

async def fetch_json(url):
    logging.info(f"Fetching JSON data from {url}")
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            if response.status == 200:
                json_data = await response.json()
                logging.info(f"JSON data fetched successfully from {url}")
                return json_data
            else:
                logging.error(f"Failed to fetch JSON data from {url}")
                return None

async def fetch_all_json(data_dict):
    logging.info("Fetching JSON data from all URLs")
    json_data_dict = {}
    tasks = []
    
    for key, url in data_dict.items():
        task = asyncio.create_task(fetch_json(url))
        tasks.append((key, task))
    
    for key, task in tasks:
        json_data = await task
        if json_data:
            json_data_dict[key] = json_data
    
    logging.info("JSON data fetched successfully from all URLs")
    return json_data_dict

async def save_json_data(data_dict):
    logging.info("Saving JSON data to files")
    directory = "data"
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    tasks = []
    
    for key, json_data in data_dict.items():
        filename = os.path.join(directory, f"{key}.json")
        task = asyncio.to_thread(write_json_file, filename, json_data)
        tasks.append(task)
    
    await asyncio.gather(*tasks)
    
    logging.info("JSON data saved successfully!")

import json
def write_json_file(filename, json_data):
    with open(filename, 'w') as file:
        json.dump(json_data, file)

import concurrent.futures

async def save_json_data(data_dict):
    logging.info("Saving JSON data to files")
    directory = "data"
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    tasks = []
    loop = asyncio.get_event_loop()
    
    for key, json_data in data_dict.items():
        filename = os.path.join(directory, f"{key}.json")
        task = loop.run_in_executor(None, write_json_file, filename, json_data)
        tasks.append(task)

# %%
import nest_asyncio

# Apply the nest_asyncio patch
nest_asyncio.apply()

# Now you can run your code
loop = asyncio.get_event_loop()
json_data_dict = loop.run_until_complete(fetch_all_json(data_dict))
loop.run_until_complete(save_json_data(json_data_dict))
# Out:
# 2024-01-20 13:32:39,863 - INFO - Fetching JSON data from all URLs
# 2024-01-20 13:32:39,866 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/erm2-nwe9.json
# 2024-01-20 13:32:39,870 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/3rfa-3xsf.json
# 2024-01-20 13:32:39,871 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/wewp-mm3p.json
# 2024-01-20 13:32:39,871 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/sqcr-6mww.json
# 2024-01-20 13:32:39,871 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/aiww-p3af.json
# 2024-01-20 13:32:39,872 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/cs9t-e3x8.json
# 2024-01-20 13:32:39,872 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/vwpc-kje2.json
# 2024-01-20 13:32:39,873 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/uzcy-9puk.json
# 2024-01-20 13:32:39,896 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/hy4q-igkk.json
# 2024-01-20 13:32:39,898 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/sxmw-f24h.json
# 2024-01-20 13:32:39,901 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/dzvt-6g3v.json
# 2024-01-20 13:32:39,904 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/wymh-dvmd.json
# 2024-01-20 13:32:39,905 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/kjxa-7ccf.json
# 2024-01-20 13:32:39,906 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/b4mf-rg6h.json
# 2024-01-20 13:32:39,906 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/9y7k-h295.json
# 2024-01-20 13:32:39,907 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/9jgj-bmct.json
# 2024-01-20 13:32:39,908 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/cwy2-px8b.json
# 2024-01-20 13:32:39,908 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/mu46-p9is.json
# 2024-01-20 13:32:39,909 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/rn6p-xvjd.json
# 2024-01-20 13:32:39,910 - INFO - Fetching JSON data from https://data.cityofnewyork.us/resource/i2y3-sx2e.json
# 2024-01-20 13:32:40,480 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/dzvt-6g3v.json
# 2024-01-20 13:32:40,482 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/9y7k-h295.json
# 2024-01-20 13:32:40,517 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/wymh-dvmd.json
# 2024-01-20 13:32:40,518 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/kjxa-7ccf.json
# 2024-01-20 13:32:40,524 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/rn6p-xvjd.json
# 2024-01-20 13:32:40,543 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/cs9t-e3x8.json
# 2024-01-20 13:32:40,550 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/sxmw-f24h.json
# 2024-01-20 13:32:40,558 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/wewp-mm3p.json
# 2024-01-20 13:32:40,569 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/i2y3-sx2e.json
# 2024-01-20 13:32:40,582 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/aiww-p3af.json
# 2024-01-20 13:32:40,771 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/sqcr-6mww.json
# 2024-01-20 13:32:40,778 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/vwpc-kje2.json
# 2024-01-20 13:32:40,785 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/cwy2-px8b.json
# 2024-01-20 13:32:40,896 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/uzcy-9puk.json
# 2024-01-20 13:32:40,901 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/hy4q-igkk.json
# 2024-01-20 13:32:40,906 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/9jgj-bmct.json
# 2024-01-20 13:32:40,909 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/b4mf-rg6h.json
# 2024-01-20 13:32:40,913 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/3rfa-3xsf.json
# 2024-01-20 13:32:41,846 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/mu46-p9is.json
# 2024-01-20 13:32:45,670 - INFO - JSON data fetched successfully from https://data.cityofnewyork.us/resource/erm2-nwe9.json
# 2024-01-20 13:32:45,672 - INFO - JSON data fetched successfully from all URLs
# 2024-01-20 13:32:45,690 - INFO - Saving JSON data to files

# %%
import os
import pandas as pd

# Specify the directory path
directory = "data"

# Initialize lists to store file names and sizes
file_names = []
file_sizes_gb = []

# Iterate over the files in the directory
for file_name in os.listdir(directory):
    file_path = os.path.join(directory, file_name)
    if os.path.isfile(file_path):
        # Get the file size in bytes
        file_size_bytes = os.path.getsize(file_path)
        # Convert the file size to GB
        file_size_gb = file_size_bytes / (1024**3)
        # Append the file name and size to the lists
        file_names.append(file_name)
        file_sizes_gb.append(file_size_gb)

# Create the pandas dataframe
df = pd.DataFrame({'File Name': file_names, 'Size (GB)': file_sizes_gb})

# Print the dataframe
df
# Out:
#                                             File Name  Size (GB)
# 0   Local-Law-8-of-2020-Complaints-of-Illegal-Park...   0.001308
# 1   Inspections-of-Municipal-Solid-Waste-Disposal-...   0.000110
# 2                                Curb-Metal-Data.json   0.000283
# 3                        311-Call-Center-Inquiry.json   0.000354
# 4   Local-Law-8-of-2020-Report-Monthly-Complaints-...   0.000055
# 5                      DOHMH-Call-Center-Summary.json   0.000027
# 6                  311-Service-Requests-for-2006.json   0.000782
# 7                   311-Service-Level-Agreements.json   0.000177
# 8                       311-Web-Content-Services.json   0.001001
# 9                  311-Service-Requests-for-2007.json   0.000827
# 10                     311-Interpreter-Wait-Time.json   0.000084
# 11                 311-Service-Requests-for-2008.json   0.000830
# 12                 311-Service-Requests-for-2004.json   0.000750
# 13                 311-Service-Requests-for-2005.json   0.000768
# 14                 Commissioner-s-Correspondence.json   0.000437
# 15                 311-Service-Requests-for-2009.json   0.000829
# 16     311-Service-Requests-from-2010-to-Present.json   0.001329
# 17         DOHMH-Indoor-Environmental-Complaints.json   0.000547
# 18                     Forestry-Service-Requests.json   0.000980
# 19      SCOUT-Street-Condition-Observation-Unit-.json   0.000046

# %%
import os
import pandas as pd

# Specify the directory path
directory = "data"

# Initialize lists to store file names, sizes, and row counts
file_names = []
file_sizes_gb = []
row_counts = []

# Iterate over the files in the directory
for file_name in os.listdir(directory):
    file_path = os.path.join(directory, file_name)
    if os.path.isfile(file_path):
        # Get the file size in bytes
        file_size_bytes = os.path.getsize(file_path)
        # Convert the file size to GB
        file_size_gb = file_size_bytes / (1024**3)
        # Append the file name and size to the lists
        file_names.append(file_name)
        file_sizes_gb.append(file_size_gb)
        
        # Read the dataset file and count the number of rows
        dataset = pd.read_csv(file_path)
        row_count = len(dataset)
        row_counts.append(row_count)

# Create the pandas dataframe
df = pd.DataFrame({'File Name': file_names, 'Size (GB)': file_sizes_gb, 'Row Count': row_counts})

# Print the dataframe
df
# Out:
#                                             File Name  Size (GB)  Row Count
# 0   Local-Law-8-of-2020-Complaints-of-Illegal-Park...   0.001308          0
# 1   Inspections-of-Municipal-Solid-Waste-Disposal-...   0.000110          0
# 2                                Curb-Metal-Data.json   0.000283          0
# 3                        311-Call-Center-Inquiry.json   0.000354          0
# 4   Local-Law-8-of-2020-Report-Monthly-Complaints-...   0.000055          0
# 5                      DOHMH-Call-Center-Summary.json   0.000027          0
# 6                  311-Service-Requests-for-2006.json   0.000782          0
# 7                   311-Service-Level-Agreements.json   0.000177          0
# 8                       311-Web-Content-Services.json   0.001001          0
# 9                  311-Service-Requests-for-2007.json   0.000827          0
# 10                     311-Interpreter-Wait-Time.json   0.000084          0
# 11                 311-Service-Requests-for-2008.json   0.000830          0
# 12                 311-Service-Requests-for-2004.json   0.000750          0
# 13                 311-Service-Requests-for-2005.json   0.000768          0
# 14                 Commissioner-s-Correspondence.json   0.000437          0
# 15                 311-Service-Requests-for-2009.json   0.000829          0
# 16     311-Service-Requests-from-2010-to-Present.json   0.001329          0
# 17         DOHMH-Indoor-Environmental-Complaints.json   0.000547          0
# 18                     Forestry-Service-Requests.json   0.000980          0
# 19      SCOUT-Street-Condition-Observation-Unit-.json   0.000046          0

# %%
import pandas as pd

# Read the JSON file as a dataframe
df = pd.read_json('data/311-Service-Requests-from-2010-to-Present.json')

# Print the dataframe
print(df)
# Out:
#      unique_key             created_date agency  \
# 0      60066340  2024-01-19T12:00:00.000   DSNY
# 1      60060963  2024-01-19T12:00:00.000   DSNY
# 2      60064570  2024-01-19T12:00:00.000   DSNY
# 3      60073378  2024-01-19T12:00:00.000   DSNY
# 4      60073384  2024-01-19T12:00:00.000   DSNY
# ..          ...                      ...    ...
# 995    60072457  2024-01-18T22:02:55.000    HPD
# 996    60073328  2024-01-18T22:02:31.000   NYPD
# 997    60071714  2024-01-18T22:02:27.000   DSNY
# 998    60066451  2024-01-18T22:02:20.000   DSNY
# 999    60063000  2024-01-18T22:02:00.000    DEP
#
#                                            agency_name       complaint_type  \
# 0                             Department of Sanitation    Derelict Vehicles
# 1                             Department of Sanitation    Derelict Vehicles
# 2                             Department of Sanitation    Derelict Vehicles
# 3                             Department of Sanitation    Derelict Vehicles
# 4                             Department of Sanitation    Derelict Vehicles
# ..                                                 ...                  ...
# 995  Department of Housing Preservation and Develop...       HEAT/HOT WATER
# 996                    New York City Police Department  Noise - Residential
# 997                           Department of Sanitation          Snow or Ice
# 998                           Department of Sanitation          Snow or Ice
# 999             Department of Environmental Protection                Noise
#
#                                        descriptor               location_type  \
# 0                               Derelict Vehicles                      Street
# 1                               Derelict Vehicles                      Street
# 2                               Derelict Vehicles                      Street
# 3                               Derelict Vehicles                      Street
# 4                               Derelict Vehicles                      Street
# ..                                            ...                         ...
# 995                                APARTMENT ONLY        RESIDENTIAL BUILDING
# 996                              Banging/Pounding  Residential Building/House
# 997                                      Sidewalk                    Sidewalk
# 998                                      Sidewalk                    Sidewalk
# 999  Noise: Construction Before/After Hours (NM1)                         NaN
#
#     intersection_street_1 intersection_street_2  address_type  ...  \
# 0          CARROLL STREET        CARROLL STREET  INTERSECTION  ...
# 1                     NaN                   NaN       ADDRESS  ...
# 2                     NaN                   NaN       ADDRESS  ...
# 3                     NaN                   NaN       ADDRESS  ...
# 4                     NaN                   NaN       ADDRESS  ...
# ..                    ...                   ...           ...  ...
# 995                   NaN                   NaN       ADDRESS  ...
# 996      EAST  232 STREET     WHITE PLAINS ROAD  INTERSECTION  ...
# 997         SANFORD PLACE     VICTORY BOULEVARD       ADDRESS  ...
# 998              6 AVENUE        CARLTON AVENUE       ADDRESS  ...
# 999                   NaN                   NaN       ADDRESS  ...
#
#     :@computed_region_7mpf_4k6g closed_date       landmark vehicle_type  \
# 0                           NaN         NaN            NaN          NaN
# 1                          44.0         NaN            NaN          NaN
# 2                          44.0         NaN            NaN          NaN
# 3                          72.0         NaN            NaN          NaN
# 4                          49.0         NaN            NaN          NaN
# ..                          ...         ...            ...          ...
# 995                        28.0         NaN            NaN          NaN
# 996                        30.0         NaN            NaN          NaN
# 997                        74.0         NaN  BRENTON PLACE          NaN
# 998                        50.0         NaN    DEAN STREET          NaN
# 999                        45.0         NaN            NaN          NaN
#
#     taxi_pick_up_location bridge_highway_name bridge_highway_direction  \
# 0                     NaN                 NaN                      NaN
# 1                     NaN                 NaN                      NaN
# 2                     NaN                 NaN                      NaN
# 3                     NaN                 NaN                      NaN
# 4                     NaN                 NaN                      NaN
# ..                    ...                 ...                      ...
# 995                   NaN                 NaN                      NaN
# 996                   NaN                 NaN                      NaN
# 997                   NaN                 NaN                      NaN
# 998                   NaN                 NaN                      NaN
# 999                   NaN                 NaN                      NaN
#
#     bridge_highway_segment road_ramp  due_date
# 0                      NaN       NaN       NaN
# 1                      NaN       NaN       NaN
# 2                      NaN       NaN       NaN
# 3                      NaN       NaN       NaN
# 4                      NaN       NaN       NaN
# ..                     ...       ...       ...
# 995                    NaN       NaN       NaN
# 996                    NaN       NaN       NaN
# 997                    NaN       NaN       NaN
# 998                    NaN       NaN       NaN
# 999                    NaN       NaN       NaN
#
# [1000 rows x 46 columns]
